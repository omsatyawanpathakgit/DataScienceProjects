# %% [markdown]
# # Customer Churn Prediction Deep Learning project:

# %%
# Import required libraries:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Ignore all warnings (if any upcoming):
import warnings
warnings.filterwarnings("ignore")

#Load the dataset:
df = pd.read_csv("customer_churn.csv")

# %%
# 5 samples of dataset:
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2944  5311-IHLEI    Male              0      No         No      12
# 1214  9866-QEVEE    Male              0      No         No      19
# 4868  2568-OIADY  Female              0     Yes         No      37
# 5021  6617-WLBQC  Female              0     Yes        Yes      23
# 3125  5222-JCXZT    Male              0      No         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 2944           No  No phone service             DSL                  Yes
# 1214          Yes               Yes     Fiber optic                   No
# 4868          Yes               Yes     Fiber optic                   No
# 5021          Yes               Yes     Fiber optic                  Yes
# 3125          Yes                No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# ...

# %%
# Drop 'customerID' column since it is of no use:
df.drop('customerID',axis='columns',inplace=True)

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6907  Female              0      No         No      41          Yes
# 924   Female              1      No         No      22          Yes
# 5716    Male              0      No        Yes       2          Yes
# 5136    Male              1      No         No       2          Yes
# 2179  Female              0      No         No       5          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 6907            No     Fiber optic                   No                   No
# 924             No     Fiber optic                  Yes                  Yes
# 5716            No             DSL                   No                   No
# 5136           Yes     Fiber optic                   No                   No
# 2179            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
# Data-types of all attributes:
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Observe values in the "TotalCharges' column:
df["TotalCharges"].values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       shape=(7043,), dtype=object)

# %%
# Convert the above values into numeric-type:

# Step1) First check for any missing values:
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Step2) Check for any blank-strings:
status=0
for i in df["TotalCharges"].values:
    if(i==" "):
        status = 1 
        break
if(status == 1):
    print("Blank-strings are located")
else:
    print("No Blank strings are observed")
# Out:
# Blank-strings are located

# %%
# We have some blank values. Hence we will set 'errors' to 'coerce':

pd.to_numeric(df["TotalCharges"],errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
#Remove rows with space in "TotalCharges" column:
df1 = df[df.TotalCharges!=' ']

# %%
#Now convert the "TotalCharges" column to numeric:

df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
#Customer Churn Prediction:
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("Tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction by Tenure")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction by Monthly Charges")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
# Now let us see unique values and their frequencies in all categorical attributes:

def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print("\n---------------------------\n\n")
                print(f'{column}: {df[column].unique()}') 
                print(f'Frequency =  {len(df[column].unique())}')
                print("\n---------------------------\n\n")
print_unique_col_values(df1)
# Out:
# ---------------------------
#
#
# gender: ['Female' 'Male']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# Partner: ['Yes' 'No']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# Dependents: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# PhoneService: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# MultipleLines: ['No phone service' 'No' 'Yes']
# Frequency =  3
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# InternetService: ['DSL' 'Fiber optic' 'No']
# Frequency =  3
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# Frequency =  3
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# OnlineBackup: ['Yes' 'No' 'No internet service']
# Frequency =  3
#
# ...

# %%
#Inspect the data:
df1.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# We observe that some columns show 'no internet service' or 'no phone service'. Let us replace them with a simple No:
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)

# %%
#Inspect the data once again:
df1.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# Let us now check again for all unique values in the categorical columns along with their frequencies:
print_unique_col_values(df1)
# Out:
# ---------------------------
#
#
# gender: ['Female' 'Male']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# Partner: ['Yes' 'No']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# Dependents: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# PhoneService: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# MultipleLines: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# InternetService: ['DSL' 'Fiber optic' 'No']
# Frequency =  3
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# OnlineSecurity: ['No' 'Yes']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# OnlineBackup: ['Yes' 'No']
# Frequency =  2
#
# ---------------------------
#
#
#
# ---------------------------
#
#
# ...

# %%
#Now we will convert all "Yes" and "No" values (in the above dataframe) to 1 and 0 respectively so that our neural network model will understand it clearly:
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
#Run the User-defined function print_unique_col_values() once again:
# Run this BEFORE df1.head()
for col in df1:
    print(f'{col}: {df1[col].unique()}') 
#print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
# Similary change Female into 1 and Male into 0 respectively:
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
df1.gender.unique()
# Out:
# array([1, 0])

# %%
# Apply one-hot encoding to categorical columns:
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                           bool
# ...

# %%
# Apply MinMaxScaling to "tenure","MonthlyCharges" and "TotalCharges" columns:
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %%
#Apply train-test split:
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
#Build a ANN model around this:
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(21, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7607 - loss: 0.4915
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7938 - loss: 0.4257
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4189
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8018 - loss: 0.4153
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.4123
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8060 - loss: 0.4096
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8055 - loss: 0.4080
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8091 - loss: 0.4059
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8073 - loss: 0.4045
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8135 - loss: 0.4040
# Epoch 11/100
# ...

# %%
#Evaluate the ANN model on test-dataset:
model.evaluate(X_test, y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7811 - loss: 0.4835
# [0.48349785804748535, 0.7810945510864258]

# %%
#Now make predictions on input type test data:
yp = model.predict(X_test)

y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
#Plot confusion matrix:
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85       999
#            1       0.62      0.62      0.62       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.73      0.73      1407
# weighted avg       0.78      0.78      0.78      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
